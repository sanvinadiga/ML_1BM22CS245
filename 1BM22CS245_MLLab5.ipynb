# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the datasets
iris_path = "/content/iris (3).csv"
diabetes_path = "/content/diabetes (1).csv"

iris_df = pd.read_csv(iris_path)
diabetes_df = pd.read_csv(diabetes_path)

# KNN for IRIS Dataset
# Splitting features and target
X_iris = iris_df.drop(columns=['species'])  # Features
y_iris = iris_df['species']  # Target

# Split into train and test sets
X_train_iris, X_test_iris, y_train_iris, y_test_iris = train_test_split(X_iris, y_iris, test_size=0.2, random_state=42)

# Finding best K value using accuracy scores
accuracy_list = []
k_range = range(1, 21)
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_iris, y_train_iris)
    y_pred_iris = knn.predict(X_test_iris)
    accuracy_list.append(accuracy_score(y_test_iris, y_pred_iris))

# Plot accuracy vs. K value
plt.figure(figsize=(10,5))
plt.plot(k_range, accuracy_list, marker='o', linestyle='dashed', color='b')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.title('KNN Accuracy for IRIS Dataset')
plt.show()

# Train final model with best K
best_k = k_range[np.argmax(accuracy_list)]
knn_iris = KNeighborsClassifier(n_neighbors=best_k)
knn_iris.fit(X_train_iris, y_train_iris)
y_pred_iris = knn_iris.predict(X_test_iris)

# Display results
print(f"Best K for IRIS: {best_k}")
print("Accuracy on IRIS dataset:", accuracy_score(y_test_iris, y_pred_iris))
print("Classification Report for IRIS:")
print(classification_report(y_test_iris, y_pred_iris))

# Confusion Matrix
conf_matrix_iris = confusion_matrix(y_test_iris, y_pred_iris)
sns.heatmap(conf_matrix_iris, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for IRIS')
plt.show()

# KNN for Diabetes Dataset
# Splitting features and target
X_diabetes = diabetes_df.drop(columns=['Outcome'])  # Features
y_diabetes = diabetes_df['Outcome']  # Target

# Split into train and test sets
X_train_diabetes, X_test_diabetes, y_train_diabetes, y_test_diabetes = train_test_split(X_diabetes, y_diabetes, test_size=0.2, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_diabetes = scaler.fit_transform(X_train_diabetes)
X_test_diabetes = scaler.transform(X_test_diabetes)

# Train KNN model
knn_diabetes = KNeighborsClassifier(n_neighbors=5)  # Default K=5
knn_diabetes.fit(X_train_diabetes, y_train_diabetes)
y_pred_diabetes = knn_diabetes.predict(X_test_diabetes)

# Display results
print("Accuracy on Diabetes dataset:", accuracy_score(y_test_diabetes, y_pred_diabetes))
print("Classification Report for Diabetes:")
print(classification_report(y_test_diabetes, y_pred_diabetes))

# Confusion Matrix
conf_matrix_diabetes = confusion_matrix(y_test_diabetes, y_pred_diabetes)
sns.heatmap(conf_matrix_diabetes, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Diabetes')
plt.show()
# Out:
# Best K for IRIS: 1
# Accuracy on IRIS dataset: 1.0
# Classification Report for IRIS:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
# Accuracy on Diabetes dataset: 0.6948051948051948
# Classification Report for Diabetes:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        99
#            1       0.58      0.51      0.54        55
#
#     accuracy                           0.69       154
#    macro avg       0.66      0.65      0.66       154
# weighted avg       0.69      0.69      0.69       154

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load the dataset
heart_path = "/content/heart (1).csv"
heart_df = pd.read_csv(heart_path)

# Splitting features and target
X_heart = heart_df.drop(columns=['target'])  # Features
y_heart = heart_df['target']  # Target

# Split into train and test sets
X_train_heart, X_test_heart, y_train_heart, y_test_heart = train_test_split(X_heart, y_heart, test_size=0.2, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_heart = scaler.fit_transform(X_train_heart)
X_test_heart = scaler.transform(X_test_heart)

# Finding best K value using accuracy scores
accuracy_list = []
k_range = range(1, 21)
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_heart, y_train_heart)
    y_pred_heart = knn.predict(X_test_heart)
    accuracy_list.append(accuracy_score(y_test_heart, y_pred_heart))

# Plot accuracy vs. K value
plt.figure(figsize=(10,5))
plt.plot(k_range, accuracy_list, marker='o', linestyle='dashed', color='b')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.title('KNN Accuracy for Heart Dataset')
plt.show()

# Train final model with best K
best_k = k_range[np.argmax(accuracy_list)]
knn_heart = KNeighborsClassifier(n_neighbors=best_k)
knn_heart.fit(X_train_heart, y_train_heart)
y_pred_heart = knn_heart.predict(X_test_heart)

# Display results
print(f"Best K for Heart Dataset: {best_k}")
print("Accuracy on Heart dataset:", accuracy_score(y_test_heart, y_pred_heart))
print("Classification Report for Heart Dataset:")
print(classification_report(y_test_heart, y_pred_heart))

# Confusion Matrix
conf_matrix_heart = confusion_matrix(y_test_heart, y_pred_heart)
sns.heatmap(conf_matrix_heart, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Heart Dataset')
plt.show()
# Out:
# Best K for Heart Dataset: 7
# Accuracy on Heart dataset: 0.9180327868852459
# Classification Report for Heart Dataset:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92        29
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
